# %%
import pandas as pd
import json
import os
import numpy as np
from datetime import date

# %%
# Define the file path (update with your actual file path)
file_path = "./data/accessible_restaurant_info.json"

# Ensure the file exists
if os.path.exists(file_path):
    # Load the JSON data
    with open(file_path, 'r') as f:
        data = json.load(f)

    # Convert the JSON data into a pandas DataFrame
    df = pd.DataFrame(data)

    # Display the DataFrame
    print(df)
else:
    print(f"File not found: {file_path}")
# Out:
#                                    name                     place_id  \
# 0           Shilo Inns Portland Airport  ChIJ1QXDFoujlVQRgiN-WQQ-hVs
# 1         Salty's on the Columbia River  ChIJh9y2IHamlVQRtYXoYQcRp_M
# 2              Beaches Restaurant & Bar  ChIJd4zRyZiolVQR2KR6dFigVKc
# 3                         Auntie Anne's  ChIJ0c6lfemvlVQRsdAxSayegxk
# 4            McMenamins on the Columbia  ChIJv21P5gOmlVQRyRmU14oj-XE
# 5                    Big Al's Vancouver  ChIJe6gnAcmklVQRSjFEVmboBDU
# 6                     Bollywood Theater  ChIJtz1JAiCnlVQRXr_iA5MFB08
# 7                                Subway  ChIJy3PYjTu7lVQRYo0TwjkKBRE
# 8                                Arby's  ChIJc-2-3Q2llVQRW5ZU1ZmuFVo
# 9                                Subway  ChIJqRNMkbevlVQRlaNo9wXk2j8
# 10                          Island Cafe  ChIJjXA77xemlVQRGOJzgFzn2Rg
# 11      Olive Garden Italian Restaurant  ChIJK_WTgJOvlVQRl_PaqFobpfE
# 12               Lakeside Bar and Grill  ChIJ42NOWh2klVQRy0wQYvIeiyw
# 13                       Portlander Inn  ChIJ07CdmTmmlVQRMqvqwazn5RM
# 14               Brickhouse Bar & Grill  ChIJmR4zyLWolVQRFGkgvwfU-0g
# 15               Thai Orchid Restaurant  ChIJeRAfLbGolVQR_JVkLqQkTg0
# 16                                 IHOP  ChIJsYPu3Q2klVQR9LBVuFdlQPU
# 17                 McGrath's Fish House  ChIJxWYE-BillVQRO1yv3y7AbUA
# 18            McMenamins East Vancouver  ChIJjznlhM-6lVQRh4bXaY0w_ig
# 19                          Burgerville  ChIJs7A2wUavlVQRWlGL02s9a3g
# 20                       Domino's Pizza  ChIJF5i879iklVQRb0Lf8dLIamU
# 21               Hudson's Bar and Grill  ChIJp2j1V5GvlVQR2cHDXRYBghA
# 22            McMenamins Kennedy School  ChIJAWbAQeimlVQR4I2f-SqmBkA
# 23               Makoto Japanese Buffet  ChIJvb8WDs6klVQRZzfxghveOM4
# 24                          Red Lobster  ChIJiRoIo5SvlVQRgwzrky-_bgI
# 25                         Jimmy John's  ChIJSdmYgxqllVQRF7jnNvqvo_o
# 26            Breakside Brewery - DEKUM  ChIJP75JbP6mlVQRHolZgS7ssRA
# 27                 Firehouse Restaurant  ChIJC2jqav6mlVQR43XeB3VVEfE
# 28                               Subway  ChIJZZUHQuKvlVQRx4oOTwlBjnE
# 29                               Subway  ChIJD8ix-kOvlVQR7EE17wua1Rk
# 30          Papa Murphy's International  ChIJy-oaCZSvlVQRGepALLoHxUM
# 31       Golden palace at battle ground  ChIJ7ZTslGK0lVQRkY4ev0IfKFA
# 32                 Tin Shed Garden Cafe  ChIJm3XIOh-nlVQRS_D47L1wsB4
# 33                               Subway  ChIJkVnp3hOklVQRe-lTG8y6Cl8
# 34                               Subway  ChIJn1oVY--tlVQRZetU278XHNM
# 35                               Subway  ChIJXznTbCGllVQR1bE9IF5PCIs
# 36                Shari's Cafe and Pies  ChIJ1QO7voqjlVQRqvWd7XCVMKQ
# 37              Famous Dave's Bar-B-Que  ChIJcVGIwQ2klVQRDK8nYVbjInQ
# 38                               Subway  ChIJaSnVD1ullVQRPJKkcAjft-Q
# 39                   Who Song & Larry's  ChIJlfPzxQOmlVQRCL5-mq3Kdrw
# 40                            Starbucks  ChIJFRsIwLColVQRcIU3MOhFklE
# 41                 Little Caesars Pizza  ChIJo3_nGYe0lVQRu84aZVmp3iQ
# 42                               Subway  ChIJb64bVYiulVQRyEngyywxFDg
# 43                               Subway  ChIJWTI8Ec6klVQRrFtOVAqVoYQ
# 44                          Burgerville  ChIJJQlZoxCllVQRvQqUrw9VqEk
# 45                     Papa Johns Pizza  ChIJXznTbCGllVQRXK8HrZNYeQE
# 46                               Subway  ChIJe1K29oG0lVQRWiK5X7Cdx0s
# 47                               Subway  ChIJkxo-Wi6ulVQRiHDpriZH46Y
# 48                         Krispy Kreme  ChIJlUrPBi6ulVQRBdhqnWrH2R8
# 49            The Old Spaghetti Factory  ChIJk74h2tOklVQRm1-xJ-1g1DE
# 50  Red Robin Gourmet Burgers and Brews  ChIJqQJ-a5OvlVQRo1C0xuciLJw
# 51                   Talay Thai Cuisine  ChIJBX-Sn0SwlVQRlvQ_AMEuREo
# 52                            Pizza Hut  ChIJYfnbEYOvlVQRaRCZhlMKhcU
# 53                          Burgerville  ChIJt4PaAOKvlVQRfLNYsf5HZLk
# 54              Menchie's Frozen Yogurt  ChIJXaDPozm7lVQRedTZScXb2m8
# 55                             Gustav's  ChIJfzXkw8iklVQR4x-Qp9Wg_L8
# 56                          Bye and Bye  ChIJMz74ExmnlVQRTrtu61B8QFk
# 57  Red Robin Gourmet Burgers and Brews  ChIJW1eGhtGklVQRuUhnAhXI2W0
# 58                      Jack in the Box  ChIJ1ZuDcI6jlVQRyFIYpawrI0E
# 59               Shanahan's Pub & Grill  ChIJXanzesqolVQRe2P9ru7bjxU
#
#    wheelchair_accessible_entrance   latitude   longitude
# 0                            True  45.567943 -122.541928
# 1                            True  45.600891 -122.624603
# 2                            True  45.614786 -122.652077
# 3                            True  45.658214 -122.583499
# 4                            True  45.615100 -122.652951
# 5                            True  45.607889 -122.500695
# 6                            True  45.559209 -122.644031
# 7                            True  45.619826 -122.477377
# 8                            True  45.621456 -122.562884
# 9                            True  45.667477 -122.602510
# 10                        Unknown  45.603536 -122.663385
# 11                           True  45.655577 -122.589220
# 12                           True  45.568815 -122.582430
# 13                           True  45.597626 -122.669939
# 14                           True  45.632260 -122.671881
# 15                           True  45.629220 -122.673366
# 16                           True  45.573544 -122.561506
# 17                           True  45.620425 -122.543323
# 18                           True  45.636979 -122.506899
# 19                           True  45.638694 -122.647234
# 20                           True  45.617609 -122.527416
# 21                           True  45.653553 -122.591905
# 22                           True  45.564491 -122.630006
# 23                           True  45.613165 -122.504891
# 24                           True  45.656485 -122.588275
# 25                           True  45.618730 -122.553569
# 26                           True  45.571565 -122.656877
# 27                           True  45.571987 -122.657437
# 28                           True  45.663851 -122.561018
# 29                           True  45.638185 -122.641504
# 30                           True  45.655134 -122.592058
# 31                           True  45.780518 -122.541834
# 32                           True  45.558964 -122.650876
# 33                           True  45.577278 -122.566387
# 34                           True  45.716690 -122.650488
# 35                           True  45.619669 -122.533077
# 36                           True  45.568518 -122.544563
# 37                           True  45.574024 -122.560454
# 38                           True  45.642108 -122.555777
# 39                           True  45.620830 -122.671180
# 40                           True  45.627443 -122.674227
# 41                           True  45.781285 -122.551447
# 42                           True  45.687037 -122.666636
# 43                           True  45.612844 -122.504590
# 44                           True  45.621067 -122.551664
# 45                           True  45.619542 -122.533036
# 46                           True  45.781334 -122.561814
# 47                           True  45.685366 -122.601903
# 48                           True  45.683726 -122.601430
# 49                           True  45.616224 -122.507940
# 50                           True  45.655273 -122.587601
# 51                           True  45.684953 -122.533299
# 52                           True  45.645043 -122.602819
# 53                           True  45.664873 -122.560808
# 54                           True  45.616501 -122.476576
# 55                           True  45.608269 -122.503469
# 56                           True  45.559308 -122.655213
# 57                           True  45.615491 -122.507146
# 58                           True  45.564941 -122.532749
# 59                           True  45.634603 -122.673062

# %%
df
# Out:
#                                    name                     place_id  \
# 0           Shilo Inns Portland Airport  ChIJ1QXDFoujlVQRgiN-WQQ-hVs
# 1         Salty's on the Columbia River  ChIJh9y2IHamlVQRtYXoYQcRp_M
# 2              Beaches Restaurant & Bar  ChIJd4zRyZiolVQR2KR6dFigVKc
# 3                         Auntie Anne's  ChIJ0c6lfemvlVQRsdAxSayegxk
# 4            McMenamins on the Columbia  ChIJv21P5gOmlVQRyRmU14oj-XE
# 5                    Big Al's Vancouver  ChIJe6gnAcmklVQRSjFEVmboBDU
# 6                     Bollywood Theater  ChIJtz1JAiCnlVQRXr_iA5MFB08
# 7                                Subway  ChIJy3PYjTu7lVQRYo0TwjkKBRE
# 8                                Arby's  ChIJc-2-3Q2llVQRW5ZU1ZmuFVo
# 9                                Subway  ChIJqRNMkbevlVQRlaNo9wXk2j8
# 10                          Island Cafe  ChIJjXA77xemlVQRGOJzgFzn2Rg
# 11      Olive Garden Italian Restaurant  ChIJK_WTgJOvlVQRl_PaqFobpfE
# 12               Lakeside Bar and Grill  ChIJ42NOWh2klVQRy0wQYvIeiyw
# 13                       Portlander Inn  ChIJ07CdmTmmlVQRMqvqwazn5RM
# 14               Brickhouse Bar & Grill  ChIJmR4zyLWolVQRFGkgvwfU-0g
# 15               Thai Orchid Restaurant  ChIJeRAfLbGolVQR_JVkLqQkTg0
# 16                                 IHOP  ChIJsYPu3Q2klVQR9LBVuFdlQPU
# 17                 McGrath's Fish House  ChIJxWYE-BillVQRO1yv3y7AbUA
# 18            McMenamins East Vancouver  ChIJjznlhM-6lVQRh4bXaY0w_ig
# 19                          Burgerville  ChIJs7A2wUavlVQRWlGL02s9a3g
# 20                       Domino's Pizza  ChIJF5i879iklVQRb0Lf8dLIamU
# 21               Hudson's Bar and Grill  ChIJp2j1V5GvlVQR2cHDXRYBghA
# 22            McMenamins Kennedy School  ChIJAWbAQeimlVQR4I2f-SqmBkA
# 23               Makoto Japanese Buffet  ChIJvb8WDs6klVQRZzfxghveOM4
# 24                          Red Lobster  ChIJiRoIo5SvlVQRgwzrky-_bgI
# 25                         Jimmy John's  ChIJSdmYgxqllVQRF7jnNvqvo_o
# 26            Breakside Brewery - DEKUM  ChIJP75JbP6mlVQRHolZgS7ssRA
# 27                 Firehouse Restaurant  ChIJC2jqav6mlVQR43XeB3VVEfE
# 28                               Subway  ChIJZZUHQuKvlVQRx4oOTwlBjnE
# 29                               Subway  ChIJD8ix-kOvlVQR7EE17wua1Rk
# 30          Papa Murphy's International  ChIJy-oaCZSvlVQRGepALLoHxUM
# 31       Golden palace at battle ground  ChIJ7ZTslGK0lVQRkY4ev0IfKFA
# 32                 Tin Shed Garden Cafe  ChIJm3XIOh-nlVQRS_D47L1wsB4
# 33                               Subway  ChIJkVnp3hOklVQRe-lTG8y6Cl8
# 34                               Subway  ChIJn1oVY--tlVQRZetU278XHNM
# 35                               Subway  ChIJXznTbCGllVQR1bE9IF5PCIs
# 36                Shari's Cafe and Pies  ChIJ1QO7voqjlVQRqvWd7XCVMKQ
# 37              Famous Dave's Bar-B-Que  ChIJcVGIwQ2klVQRDK8nYVbjInQ
# 38                               Subway  ChIJaSnVD1ullVQRPJKkcAjft-Q
# 39                   Who Song & Larry's  ChIJlfPzxQOmlVQRCL5-mq3Kdrw
# 40                            Starbucks  ChIJFRsIwLColVQRcIU3MOhFklE
# 41                 Little Caesars Pizza  ChIJo3_nGYe0lVQRu84aZVmp3iQ
# 42                               Subway  ChIJb64bVYiulVQRyEngyywxFDg
# 43                               Subway  ChIJWTI8Ec6klVQRrFtOVAqVoYQ
# 44                          Burgerville  ChIJJQlZoxCllVQRvQqUrw9VqEk
# 45                     Papa Johns Pizza  ChIJXznTbCGllVQRXK8HrZNYeQE
# 46                               Subway  ChIJe1K29oG0lVQRWiK5X7Cdx0s
# 47                               Subway  ChIJkxo-Wi6ulVQRiHDpriZH46Y
# 48                         Krispy Kreme  ChIJlUrPBi6ulVQRBdhqnWrH2R8
# 49            The Old Spaghetti Factory  ChIJk74h2tOklVQRm1-xJ-1g1DE
# 50  Red Robin Gourmet Burgers and Brews  ChIJqQJ-a5OvlVQRo1C0xuciLJw
# 51                   Talay Thai Cuisine  ChIJBX-Sn0SwlVQRlvQ_AMEuREo
# 52                            Pizza Hut  ChIJYfnbEYOvlVQRaRCZhlMKhcU
# 53                          Burgerville  ChIJt4PaAOKvlVQRfLNYsf5HZLk
# 54              Menchie's Frozen Yogurt  ChIJXaDPozm7lVQRedTZScXb2m8
# 55                             Gustav's  ChIJfzXkw8iklVQR4x-Qp9Wg_L8
# 56                          Bye and Bye  ChIJMz74ExmnlVQRTrtu61B8QFk
# 57  Red Robin Gourmet Burgers and Brews  ChIJW1eGhtGklVQRuUhnAhXI2W0
# 58                      Jack in the Box  ChIJ1ZuDcI6jlVQRyFIYpawrI0E
# 59               Shanahan's Pub & Grill  ChIJXanzesqolVQRe2P9ru7bjxU
#
#    wheelchair_accessible_entrance   latitude   longitude
# 0                            True  45.567943 -122.541928
# 1                            True  45.600891 -122.624603
# 2                            True  45.614786 -122.652077
# 3                            True  45.658214 -122.583499
# 4                            True  45.615100 -122.652951
# 5                            True  45.607889 -122.500695
# 6                            True  45.559209 -122.644031
# 7                            True  45.619826 -122.477377
# 8                            True  45.621456 -122.562884
# 9                            True  45.667477 -122.602510
# 10                        Unknown  45.603536 -122.663385
# 11                           True  45.655577 -122.589220
# 12                           True  45.568815 -122.582430
# 13                           True  45.597626 -122.669939
# 14                           True  45.632260 -122.671881
# 15                           True  45.629220 -122.673366
# 16                           True  45.573544 -122.561506
# 17                           True  45.620425 -122.543323
# 18                           True  45.636979 -122.506899
# 19                           True  45.638694 -122.647234
# 20                           True  45.617609 -122.527416
# 21                           True  45.653553 -122.591905
# 22                           True  45.564491 -122.630006
# 23                           True  45.613165 -122.504891
# 24                           True  45.656485 -122.588275
# 25                           True  45.618730 -122.553569
# 26                           True  45.571565 -122.656877
# 27                           True  45.571987 -122.657437
# 28                           True  45.663851 -122.561018
# 29                           True  45.638185 -122.641504
# 30                           True  45.655134 -122.592058
# 31                           True  45.780518 -122.541834
# 32                           True  45.558964 -122.650876
# 33                           True  45.577278 -122.566387
# 34                           True  45.716690 -122.650488
# 35                           True  45.619669 -122.533077
# 36                           True  45.568518 -122.544563
# 37                           True  45.574024 -122.560454
# 38                           True  45.642108 -122.555777
# 39                           True  45.620830 -122.671180
# 40                           True  45.627443 -122.674227
# 41                           True  45.781285 -122.551447
# 42                           True  45.687037 -122.666636
# 43                           True  45.612844 -122.504590
# 44                           True  45.621067 -122.551664
# 45                           True  45.619542 -122.533036
# 46                           True  45.781334 -122.561814
# 47                           True  45.685366 -122.601903
# 48                           True  45.683726 -122.601430
# 49                           True  45.616224 -122.507940
# 50                           True  45.655273 -122.587601
# 51                           True  45.684953 -122.533299
# 52                           True  45.645043 -122.602819
# 53                           True  45.664873 -122.560808
# 54                           True  45.616501 -122.476576
# 55                           True  45.608269 -122.503469
# 56                           True  45.559308 -122.655213
# 57                           True  45.615491 -122.507146
# 58                           True  45.564941 -122.532749
# 59                           True  45.634603 -122.673062

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 5 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   name                            60 non-null     object
#  1   place_id                        60 non-null     object
#  2   wheelchair_accessible_entrance  60 non-null     object
#  3   latitude                        60 non-null     float64
#  4   longitude                       60 non-null     float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ KB

# %%
df.isnull().sum()
# Out:
# name                              0
# place_id                          0
# wheelchair_accessible_entrance    0
# latitude                          0
# longitude                         0
# dtype: int64

# %%
accessible_df = df[df['wheelchair_accessible_entrance'] == True]
accessible_df.head()
# Out:
#                             name                     place_id  \
# 0    Shilo Inns Portland Airport  ChIJ1QXDFoujlVQRgiN-WQQ-hVs
# 1  Salty's on the Columbia River  ChIJh9y2IHamlVQRtYXoYQcRp_M
# 2       Beaches Restaurant & Bar  ChIJd4zRyZiolVQR2KR6dFigVKc
# 3                  Auntie Anne's  ChIJ0c6lfemvlVQRsdAxSayegxk
# 4     McMenamins on the Columbia  ChIJv21P5gOmlVQRyRmU14oj-XE
#
#   wheelchair_accessible_entrance   latitude   longitude
# 0                           True  45.567943 -122.541928
# 1                           True  45.600891 -122.624603
# 2                           True  45.614786 -122.652077
# 3                           True  45.658214 -122.583499
# 4                           True  45.615100 -122.652951

# %%
# Add new columns with "Unknown" as the default value
df['wheelchair_accessible_parking'] = "Unknown"
df['wheelchair_accessible_restroom'] = "Unknown"
df['wheelchair_accessible_seating'] = "Unknown"

# Display the updated DataFrame
df.head()
# Out:
#                             name                     place_id  \
# 0    Shilo Inns Portland Airport  ChIJ1QXDFoujlVQRgiN-WQQ-hVs
# 1  Salty's on the Columbia River  ChIJh9y2IHamlVQRtYXoYQcRp_M
# 2       Beaches Restaurant & Bar  ChIJd4zRyZiolVQR2KR6dFigVKc
# 3                  Auntie Anne's  ChIJ0c6lfemvlVQRsdAxSayegxk
# 4     McMenamins on the Columbia  ChIJv21P5gOmlVQRyRmU14oj-XE
#
#   wheelchair_accessible_entrance   latitude   longitude  \
# 0                           True  45.567943 -122.541928
# 1                           True  45.600891 -122.624603
# 2                           True  45.614786 -122.652077
# 3                           True  45.658214 -122.583499
# 4                           True  45.615100 -122.652951
#
#   wheelchair_accessible_parking wheelchair_accessible_restroom  \
# 0                       Unknown                        Unknown
# 1                       Unknown                        Unknown
# 2                       Unknown                        Unknown
# 3                       Unknown                        Unknown
# 4                       Unknown                        Unknown
#
#   wheelchair_accessible_seating
# 0                       Unknown
# 1                       Unknown
# 2                       Unknown
# 3                       Unknown
# 4                       Unknown

# %%
# Desired column order
new_column_order = [
    "name", 
    "wheelchair_accessible_entrance", 
    "wheelchair_accessible_parking", 
    "wheelchair_accessible_restroom", 
    "wheelchair_accessible_seating",
    "latitude", 
    "longitude", 
    "place_id" 
]

# Reassign the DataFrame with the new column order
df = df[new_column_order]

# Display the DataFrame to check the new column order
df.head()
# Out:
#                             name wheelchair_accessible_entrance  \
# 0    Shilo Inns Portland Airport                           True
# 1  Salty's on the Columbia River                           True
# 2       Beaches Restaurant & Bar                           True
# 3                  Auntie Anne's                           True
# 4     McMenamins on the Columbia                           True
#
#   wheelchair_accessible_parking wheelchair_accessible_restroom  \
# 0                       Unknown                        Unknown
# 1                       Unknown                        Unknown
# 2                       Unknown                        Unknown
# 3                       Unknown                        Unknown
# 4                       Unknown                        Unknown
#
#   wheelchair_accessible_seating   latitude   longitude  \
# 0                       Unknown  45.567943 -122.541928
# 1                       Unknown  45.600891 -122.624603
# 2                       Unknown  45.614786 -122.652077
# 3                       Unknown  45.658214 -122.583499
# 4                       Unknown  45.615100 -122.652951
#
#                       place_id
# 0  ChIJ1QXDFoujlVQRgiN-WQQ-hVs
# 1  ChIJh9y2IHamlVQRtYXoYQcRp_M
# 2  ChIJd4zRyZiolVQR2KR6dFigVKc
# 3  ChIJ0c6lfemvlVQRsdAxSayegxk
# 4  ChIJv21P5gOmlVQRyRmU14oj-XE

# %%
# Define the directory and file name
directory = "./data/"

# Use today's date in the filename
file_name = f"{date.today()}_accessible_restaurant_info.json"

# Create the full file path
file_path = os.path.join(directory, file_name)

# Save the DataFrame to the JSON file with the full file path
df.to_json(file_path, orient="records", indent=4)
